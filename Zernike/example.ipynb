# %% [markdown]
# # Zernike Polynomials

# %%
import matplotlib.pyplot as plt

from zernike.plot_zernike import *
from zernike.plot_psf import *
from zernike.plot_poly import *

# %%
plot_zernike()

# %%
plot_psf()

# %%
plot_poly("S")

# %%
plot_poly("P")
